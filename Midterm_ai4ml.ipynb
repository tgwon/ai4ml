# %% [markdown]
# <a href="https://colab.research.google.com/github/tgwon/ai4ml/blob/main/Midterm_ai4ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mid-term exam on Machine Learning for AI
#
# - Name:
# - ID Number:
#
# ------------------------------------------
# Copy this notebook to your google drive.
# Good luck! :)

# %%
import pandas as pd

# %% [markdown]
# Downloading datasets

# %%
# !gdown --id 1uAgj40UQKq2bO_OBVEqr0lihB0p2DjTb
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1uAgj40UQKq2bO_OBVEqr0lihB0p2DjTb
# To: /content/covid19_cases.csv
# 100% 3.06M/3.06M [00:00<00:00, 20.2MB/s]

# %%
covid = pd.read_csv('covid19_cases.csv').assign(
    dateRep=lambda x: pd.to_datetime(x.dateRep, format='%d/%m/%Y')
)

# %%
covid.head()
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-09-19   19      9  2020     47       1             Afghanistan    AF
# 1 2020-09-18   18      9  2020      0       0             Afghanistan    AF
# 2 2020-09-17   17      9  2020     17       0             Afghanistan    AF
# 3 2020-09-16   16      9  2020     40      10             Afghanistan    AF
# 4 2020-09-15   15      9  2020     99       6             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           1.616645
# 1                                           1.535155
# 2                                           1.653446
# 3                                           1.708649
# 4                                           1.627159

# %% [markdown]
# ### Q1 From Covid19 data (covid), try to set 'dateRep' as index

# %%
covid.head(2)
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-09-19   19      9  2020     47       1             Afghanistan    AF
# 1 2020-09-18   18      9  2020      0       0             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           1.616645
# 1                                           1.535155

# %%
# 정답
covid.set_index('dateRep', inplace = True)

# %%
covid.head(2)
# Out:
#             day  month  year  cases  deaths countriesAndTerritories geoId  \
# dateRep
# 2020-09-19   19      9  2020     47       1             Afghanistan    AF
# 2020-09-18   18      9  2020      0       0             Afghanistan    AF
#
#            countryterritoryCode  popData2019 continentExp  \
# dateRep
# 2020-09-19                  AFG   38041757.0         Asia
# 2020-09-18                  AFG   38041757.0         Asia
#
#             Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# dateRep
# 2020-09-19                                           1.616645
# 2020-09-18                                           1.535155

# %% [markdown]
# ### Q2 How many unique countries in the covid data?

# %%
# 정답
covid.countriesAndTerritories.nunique()
# Out:
# 210

# %% [markdown]
# Your answer here:

# %% [markdown]
# ### Q3 Let's take subset of the covid data that meets following conditions:
#  - Country names starting with A.
#  - Months of May, June, and July on 2020

# %%
## Your code here
covid.head()
# Out:
#             day  month  year  cases  deaths countriesAndTerritories geoId  \
# dateRep
# 2020-09-19   19      9  2020     47       1             Afghanistan    AF
# 2020-09-18   18      9  2020      0       0             Afghanistan    AF
# 2020-09-17   17      9  2020     17       0             Afghanistan    AF
# 2020-09-16   16      9  2020     40      10             Afghanistan    AF
# 2020-09-15   15      9  2020     99       6             Afghanistan    AF
#
#            countryterritoryCode  popData2019 continentExp  \
# dateRep
# 2020-09-19                  AFG   38041757.0         Asia
# 2020-09-18                  AFG   38041757.0         Asia
# 2020-09-17                  AFG   38041757.0         Asia
# 2020-09-16                  AFG   38041757.0         Asia
# 2020-09-15                  AFG   38041757.0         Asia
#
#             Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# dateRep
# 2020-09-19                                           1.616645
# 2020-09-18                                           1.535155
# 2020-09-17                                           1.653446
# 2020-09-16                                           1.708649
# 2020-09-15                                           1.627159

# %%
# 정답
covid = covid[covid.countriesAndTerritories.str.startswith('A')]
subset = covid[((covid.month == 5) | (covid.month == 6) | (covid.month == 7)) & (covid.year == 2020)]
subset.head()
# Out:
#             day  month  year  cases  deaths countriesAndTerritories geoId  \
# dateRep
# 2020-07-31   31      7  2020     71       0             Afghanistan    AF
# 2020-07-30   30      7  2020      0       0             Afghanistan    AF
# 2020-07-29   29      7  2020    103       1             Afghanistan    AF
# 2020-07-28   28      7  2020    105       1             Afghanistan    AF
# 2020-07-27   27      7  2020    106      10             Afghanistan    AF
#
#            countryterritoryCode  popData2019 continentExp  \
# dateRep
# 2020-07-31                  AFG   38041757.0         Asia
# 2020-07-30                  AFG   38041757.0         Asia
# 2020-07-29                  AFG   38041757.0         Asia
# 2020-07-28                  AFG   38041757.0         Asia
# 2020-07-27                  AFG   38041757.0         Asia
#
#             Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# dateRep
# 2020-07-31                                           3.869432
# 2020-07-30                                           3.882576
# 2020-07-29                                           4.550263
# 2020-07-28                                           5.028685
# 2020-07-27                                           4.763187

# %% [markdown]
# ### Q4 Change the processed data as wide format for countryterritoryCode for cases and deaths variables.
#
# The result should look like below:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In case you couldn't sove Q3, You can start from 'newd' dataset below.

# %%
# !gdown --id 19nNmArPvrKzJ0EpU8NpE80kegkQqTDNd
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=19nNmArPvrKzJ0EpU8NpE80kegkQqTDNd
# To: /content/processed_Q3.csv
# 100% 84.3k/84.3k [00:00<00:00, 5.55MB/s]

# %%
newd = pd.read_csv('processed_Q3.csv').assign(
        dateRep=lambda x: pd.to_datetime(x.dateRep) ).set_index('dateRep')

# %%
## Your codes here
newd.head()
# Out:
#             day  month  year  cases  deaths countriesAndTerritories geoId  \
# dateRep
# 2020-05-01    1      5  2020      2       0                 Andorra    AD
# 2020-05-01    1      5  2020     60       4                 Austria    AT
# 2020-05-01    1      5  2020    143       4               Argentina    AR
# 2020-05-01    1      5  2020      0       0     Antigua_and_Barbuda    AG
# 2020-05-01    1      5  2020      0       0                  Angola    AO
#
#            countryterritoryCode  popData2019 continentExp  \
# dateRep
# 2020-05-01                  AND      76177.0       Europe
# 2020-05-01                  AUT    8858775.0       Europe
# 2020-05-01                  ARG   44780675.0      America
# 2020-05-01                  ATG      97115.0      America
# 2020-05-01                  AGO   31825299.0       Africa
#
#             Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# dateRep
# 2020-05-01                                          82.702128
# 2020-05-01                                          11.017325
# 2020-05-01                                           4.142412
# 2020-05-01                                           1.029707
# 2020-05-01                                           0.025137

# %%
# 정답
newd.pivot(columns = 'countriesAndTerritories', values = ['cases','deaths'])
# Out:
#                               cases                                          \
# countriesAndTerritories Afghanistan Albania Algeria Andorra Angola Anguilla
# dateRep
# 2020-05-01                      222       7     158       2      0        0
# 2020-05-02                      164       9     148       1      2        0
# 2020-05-03                      134       7     141       1      6        0
# 2020-05-04                      235       6     179       1      0        0
# 2020-05-05                      190       8     174       2      0        0
# ...                             ...     ...     ...     ...    ...      ...
# 2020-07-27                      106     126     593       0     50        0
# 2020-07-28                      105     117     616      10      2        0
# 2020-07-29                      103     117     642       0     18        0
# 2020-07-30                        0     108     614      11     50        0
# 2020-07-31                       71      92     602       4     78        0
#
#                                                                      ...  \
# countriesAndTerritories Antigua_and_Barbuda Argentina Armenia Aruba  ...
# dateRep                                                              ...
# 2020-05-01                                0       143      82     0  ...
# 2020-05-02                                1       104     125     0  ...
# 2020-05-03                                0       149     113     0  ...
# 2020-05-04                                0       102     121     0  ...
# 2020-05-05                                0       104     112     0  ...
# ...                                     ...       ...     ...   ...  ...
# 2020-07-27                                0      9006      73     0  ...
# 2020-07-28                                4         0     239     0  ...
# 2020-07-29                                0      4890     308     0  ...
# 2020-07-30                                5      5939     259     0  ...
# 2020-07-31                                0      5641     354     1  ...
#
#                          deaths                                                \
# countriesAndTerritories Andorra Angola Anguilla Antigua_and_Barbuda Argentina
# dateRep
# 2020-05-01                    0      0        0                   0         4
# 2020-05-02                    1      0        0                   0         7
# 2020-05-03                    1      0        0                   0        12
# 2020-05-04                    1      0        0                   0         9
# 2020-05-05                    0      0        0                   0        14
# ...                         ...    ...      ...                 ...       ...
# 2020-07-27                    0      5        0                   0        92
# 2020-07-28                    0      0        0                   0        17
# 2020-07-29                    0      1        0                   0       126
# 2020-07-30                    0      6        0                   0       118
# 2020-07-31                    0      1        0                   0       111
#
#
# countriesAndTerritories Armenia Aruba Australia Austria Azerbaijan
# dateRep
# 2020-05-01                    1     0         2       4          1
# 2020-05-02                    0     0         1       5          1
# 2020-05-03                    2     0         0       7          0
# 2020-05-04                    4     0         2       2          0
# 2020-05-05                    1     0         0       2          1
# ...                         ...   ...       ...     ...        ...
# 2020-07-27                    6     0        10       0          9
# 2020-07-28                    8     0         6       1          6
# 2020-07-29                    4     0         6       0          7
# 2020-07-30                    5     0         9       3          8
# 2020-07-31                   10     0        13       2          3
#
# [92 rows x 26 columns]

# %% [markdown]
# ### Q5 Which country has the highest cumulative number of confirmed cases among countries with country names beginning with A? What is that cumulative number of the country?

# %% [markdown]
# In case you couldn't sove Q4, You can start from 'newd2' dataset below

# %%
# !gdown --id 1VHsC88bw46y8kMOKA0HsCMwhOPGyB4GV
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1VHsC88bw46y8kMOKA0HsCMwhOPGyB4GV
# To: /content/processed_covid.csv
# 100% 4.79k/4.79k [00:00<00:00, 15.9MB/s]

# %%
newd2 = pd.read_csv('processed_covid.csv').assign(
        dateRep=lambda x: pd.to_datetime(x.dateRep) ).set_index('dateRep')

# %%
### Your code here:
newd2.head()
# Out:
#             Afghanistan  Albania  Algeria  Andorra  Angola  Anguilla  \
# dateRep
# 2020-05-01          222        7      158        2       0         0
# 2020-05-02          164        9      148        1       2         0
# 2020-05-03          134        7      141        1       6         0
# 2020-05-04          235        6      179        1       0         0
# 2020-05-05          190        8      174        2       0         0
#
#             Antigua_and_Barbuda  Argentina  Armenia  Aruba  Australia  \
# dateRep
# 2020-05-01                    0        143       82      0         16
# 2020-05-02                    1        104      125      0          5
# 2020-05-03                    0        149      113      0         16
# 2020-05-04                    0        102      121      0         18
# 2020-05-05                    0        104      112      0         24
#
#             Austria  Azerbaijan
# dateRep
# 2020-05-01       60          38
# 2020-05-02       34          50
# 2020-05-03       12          40
# 2020-05-04       68          38
# 2020-05-05       31          52

# %%
newd2.tail()
# Out:
#             Afghanistan  Albania  Algeria  Andorra  Angola  Anguilla  \
# dateRep
# 2020-07-27          106      126      593        0      50         0
# 2020-07-28          105      117      616       10       2         0
# 2020-07-29          103      117      642        0      18         0
# 2020-07-30            0      108      614       11      50         0
# 2020-07-31           71       92      602        4      78         0
#
#             Antigua_and_Barbuda  Argentina  Armenia  Aruba  Australia  \
# dateRep
# 2020-07-27                    0       9006       73      0        453
# 2020-07-28                    4          0      239      0        532
# 2020-07-29                    0       4890      308      0        369
# 2020-07-30                    5       5939      259      0        278
# 2020-07-31                    0       5641      354      1        721
#
#             Austria  Azerbaijan
# dateRep
# 2020-07-27      137         417
# 2020-07-28       64         396
# 2020-07-29      132         412
# 2020-07-30      164         363
# 2020-07-31      163         339

# %%
newd2.cumsum().loc['2020-07-31'].nlargest(n=1)

# 정답 : Argentina, 174711
# Out:
# Argentina    174711
# Name: 2020-07-31 00:00:00, dtype: int64

# %% [markdown]
# ### Q6 Make a line plot for following four countries, 'Argentina', 'Afghanistan', 'Armenia', and 'Algeria'. You can start from newd2 data used from Q5.
#
# The result should look like below:
# ![image.png](data:image/png;base64,...)

# %%
### Your code here:

# %% [markdown]
# ### Q7 Use rolling 7 days median for cases variable to smooth the previous visualization
#
# The result should look like below:
# ![image.png](data:image/png;base64,...)

# %%
### Your code here:

# %% [markdown]
# ### Q8 Read the following data preprocessed from Q3 ('newd'). Do the followings:
#  - Select 'cases',	'deaths',	'countriesAndTerritories' variables.
#  - Calculate total number of cases for each day (Hint: you can use groupby)
#  - Add daily total cases variable to the original data, 'newd' having three variables ('cases',	'deaths',	'countriesAndTerritories') (Hint: you can use transform() )
#
#  The result should look like below:
#  ![image.png](data:image/png;base64,...)

# %%
# !gdown --id 19nNmArPvrKzJ0EpU8NpE80kegkQqTDNd
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=19nNmArPvrKzJ0EpU8NpE80kegkQqTDNd
# To: /content/processed_Q3.csv
# 100% 84.3k/84.3k [00:00<00:00, 47.9MB/s]

# %%
newd = pd.read_csv('processed_Q3.csv').assign(
        dateRep=lambda x: pd.to_datetime(x.dateRep) ).set_index('dateRep')

# %%
### Your code here:
newd.head()
# Out:
#             day  month  year  cases  deaths countriesAndTerritories geoId  \
# dateRep
# 2020-05-01    1      5  2020      2       0                 Andorra    AD
# 2020-05-01    1      5  2020     60       4                 Austria    AT
# 2020-05-01    1      5  2020    143       4               Argentina    AR
# 2020-05-01    1      5  2020      0       0     Antigua_and_Barbuda    AG
# 2020-05-01    1      5  2020      0       0                  Angola    AO
#
#            countryterritoryCode  popData2019 continentExp  \
# dateRep
# 2020-05-01                  AND      76177.0       Europe
# 2020-05-01                  AUT    8858775.0       Europe
# 2020-05-01                  ARG   44780675.0      America
# 2020-05-01                  ATG      97115.0      America
# 2020-05-01                  AGO   31825299.0       Africa
#
#             Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# dateRep
# 2020-05-01                                          82.702128
# 2020-05-01                                          11.017325
# 2020-05-01                                           4.142412
# 2020-05-01                                           1.029707
# 2020-05-01                                           0.025137

# %%
# 정답

#newd[['cases','deaths','countriesAndTerritories']].assign(total_cases_per_day = newd.groupby(level=0).cases.sum())
newd[['cases','deaths','countriesAndTerritories']].assign(total_cases_per_day = newd.groupby(level=0).cases.transform('sum'))
# Out:
#             cases  deaths countriesAndTerritories  total_cases_per_day
# dateRep
# 2020-05-01      2       0                 Andorra                  728
# 2020-05-01     60       4                 Austria                  728
# 2020-05-01    143       4               Argentina                  728
# 2020-05-01      0       0     Antigua_and_Barbuda                  728
# 2020-05-01      0       0                  Angola                  728
# ...           ...     ...                     ...                  ...
# 2020-07-31      4       0                 Andorra                 8066
# 2020-07-31      0       0     Antigua_and_Barbuda                 8066
# 2020-07-31     92       4                 Albania                 8066
# 2020-07-31     71       0             Afghanistan                 8066
# 2020-07-31    163       2                 Austria                 8066
#
# [1196 rows x 4 columns]

# %% [markdown]
# ### Q9 Make a stacked bar plot:
#  - Start from 'newd2' dataset below.
#  - Take subset of July in 2020.
#  - Create stacked bar plot using following contries: 'Afghanistan', 'Algeria', 'Argentina', 'Armenia', 'Austria', 'Azerbaijan'.
#  - Draw stacked bar plot of number of cases for each day. We would like to see how many cases for the above contries.
#
#  The result should look like below:
#  ![image.png](data:image/png;base64,...)

# %%
# !gdown --id 1VHsC88bw46y8kMOKA0HsCMwhOPGyB4GV
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1VHsC88bw46y8kMOKA0HsCMwhOPGyB4GV
# To: /content/processed_covid.csv
# 100% 4.79k/4.79k [00:00<00:00, 5.97MB/s]

# %%
newd2 = pd.read_csv('processed_covid.csv').assign(
        dateRep=lambda x: pd.to_datetime(x.dateRep) ).set_index('dateRep')

# %%
### Your code here:

# %% [markdown]
# ### Q10 From covid19 data ('covid') do the followings
#  - Take subset of year 2020
#  - Calculate number of cases for each month for each continent ('continentExp')
#  - Visualize this information using barplot
#
#
#  The result should look like below:
#  ![image.png](data:image/png;base64,...)
#
# Barplot:
#
#
# ![image.png](data:image/png;base64,...)

# %%
### Your code here:
